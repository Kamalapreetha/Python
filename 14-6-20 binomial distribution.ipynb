# %%
from scipy.stats import binom

# %%
import seaborn as sns

# %% [markdown]
# Ques - probability of exactly getting 3 head tossing repetedly for 10 times (3/10) - binomial distribution

# %%
toss=binom.rvs(size=10000,p=0.2,n=20)

# %%
coin_toss=sns.distplot(toss,kde=True,color='blue')
